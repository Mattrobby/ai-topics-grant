# %% [markdown]
# <center><h1>Combining Plots<h1><center>
#
# ---

# %%
import data
import plotly.graph_objs as go
import plotly.express as px
import pandas as pd

rawData = data.Data()

# %%
plot1 = rawData.makeLineChart('machine learning')
plot2 = rawData.makeLineChart('artificial intelligence')

combine = go.Figure(data=plot1.data + plot2.data)
combine.update_layout(title=f'SOMETHING Occurrences by Month',
                      xaxis_title='',
                      yaxis_title='',
                      legend_title='Tags',
                      )
combine.show()
# Out:
# <div>                            <div id="380b3451-457d-4730-848c-4ad2ea8f9931" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("380b3451-457d-4730-848c-4ad2ea8f9931")) {                    Plotly.newPlot(                        "380b3451-457d-4730-848c-4ad2ea8f9931",                        [{"hovertemplate":"tag=machine learning<br>date=%{x}<br>occurrences=%{y}<extra></extra>","legendgroup":"machine learning","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"machine learning","orientation":"v","showlegend":true,"x":["2007-08-31T00:00:00","2007-09-30T00:00:00","2007-10-31T00:00:00","2007-11-30T00:00:00","2007-12-31T00:00:00","2008-01-31T00:00:00","2008-02-29T00:00:00","2008-03-31T00:00:00","2008-04-30T00:00
# ...

# %%
data1 = rawData.getChartData('machine learning', None, None)
data2 = rawData.getChartData('artificial intelligence', None, None)

frames = [data1, data2]
data = pd.concat(frames)

plot = px.line(data, x='date', y='occurrences', color='tag')
plot.show()
# Out:
# <div>                            <div id="c9f7ac72-d3e5-44d7-92c8-4abf48e1f6d6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c9f7ac72-d3e5-44d7-92c8-4abf48e1f6d6")) {                    Plotly.newPlot(                        "c9f7ac72-d3e5-44d7-92c8-4abf48e1f6d6",                        [{"hovertemplate":"tag=machine learning<br>date=%{x}<br>occurrences=%{y}<extra></extra>","legendgroup":"machine learning","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"machine learning","orientation":"v","showlegend":true,"x":["2007-08-31T00:00:00","2007-09-30T00:00:00","2007-10-31T00:00:00","2007-11-30T00:00:00","2007-12-31T00:00:00","2008-01-31T00:00:00","2008-02-29T00:00:00","2008-03-31T00:00:00","2008-04-30T00:00
# ...

# %%
top_x = rawData.getTopX(7)

chart_data = []
for tag in top_x:
    chart_data.append(rawData.getChartData(tag, None, None))

top_x_data = pd.concat(chart_data)
plot_top_x = px.scatter(top_x_data, x='date', y='occurrences', color='tag')
plot_top_x.show()
